# %% [markdown]
# ## Analyzing Draft Order

# %%
import pandas as pd
import numpy as np

# %%
df_results = pd.read_csv('2023-draft-order.csv', index_col=0)

# %% [markdown]
# **Find 75th Percentile Players to Analyze as Subset**

# %%
def find_percentile(percentile, array) :
    
    array = array.dropna()
    sorted_array = array.sort_values()
    
    percentile_x = np.percentile(sorted_array, percentile)
    
    return percentile_x

# %%
vorp_75th_value = find_percentile(75, df_results['VORP'])
ppr_75th_value = find_percentile(75, df_results['PPR_Projected_2023'])

# %% [markdown]
# #### Under Valued Players by VORP

# %%
df_results[df_results['VORP']>=vorp_75th_value].sort_values('RankvsADP', ascending = False).head(n=15)
# Out:
#                  Player Team Position  PPR_Projected_2023       VORP    ADP  \
# Rank
# 27.0  Leonard Fournette  TAM       RB          225.962114  60.506670  164.0
# 54.0    Ezekiel Elliott  DAL       RB          185.091631  19.636186  145.5
# 24.0         Geno Smith  SEA       QB          305.450818  66.351748  113.0
# 40.0         Jared Goff  DET       QB          283.257415  44.158346  115.0
# 35.0       Kirk Cousins  MIN       QB          292.350294  53.251224  106.0
# 38.0       Daniel Jones  NYG       QB          287.939302  48.840232  108.0
# 28.0    Jamaal Williams  DET       RB          225.652130  60.196686   97.0
# 51.0    Jerick McKinnon  KAN       RB          194.476373  29.020929  120.0
# 46.0        Evan Engram  JAX       TE          179.315128  41.352887   88.5
# 39.0       Alvin Kamara  NOR       RB          212.411117  46.955673   78.0
# 21.0        Dalvin Cook  MIN       RB          239.356049  73.900605   59.0
# 36.0      Tyler Lockett  SEA       WR          235.036396  51.072686   73.0
# 44.0         Mike Evans  TAM       WR          226.006895  42.043185   78.5
# 34.0     Christian Kirk  JAX       WR          239.007900  55.044190   68.0
# 41.0      Brandon Aiyuk  SFO       WR          227.926204  43.962495   69.0
#
#       RankvsADP
# Rank
# 27.0      137.0
# 54.0       91.5
# 24.0       89.0
# 40.0       75.0
# 35.0       71.0
# 38.0       70.0
# 28.0       69.0
# 51.0       69.0
# 46.0       42.5
# 39.0       39.0
# 21.0       38.0
# 36.0       37.0
# 44.0       34.5
# 34.0       34.0
# 41.0       28.0

# %% [markdown]
# The above shows the top 15 **under valued** players with VORPS in the 75th percentile. This is calculated by finding the difference between a players rank by VORP (ie Rank) and the average place they are drafted in. This is represented by the **RankvsADP** column

# %% [markdown]
# #### Over Valued Players

# %%
df_results[df_results['VORP']>=vorp_75th_value].sort_values('RankvsADP').head(n=15)
# Out:
#                    Player Team Position  PPR_Projected_2023        VORP   ADP  \
# Rank
# 55.0          Cooper Kupp  LAR       WR          199.528564   15.564855   5.0
# 50.0       Garrett Wilson  NYJ       WR          214.894529   30.930819  19.0
# 29.0        Ja'Marr Chase  CIN       WR          243.438854   59.475144   3.0
# 48.0          Tee Higgins  CIN       WR          223.528072   39.564362  31.5
# 43.0           DK Metcalf  SEA       WR          227.452820   43.489110  35.5
# 33.0         Mark Andrews  BAL       TE          194.124294   56.162053  28.0
# 13.0       Saquon Barkley  NYG       RB          284.870399  119.414955   9.0
# 15.0          CeeDee Lamb  DAL       WR          300.451481  116.487772  12.0
# 3.0      Justin Jefferson  MIN       WR          366.723519  182.759809   1.0
# 30.0         Najee Harris  PIT       RB          223.932269   58.476825  28.0
# 14.0           Nick Chubb  CLE       RB          283.545676  118.090232  12.0
# 45.0       Justin Herbert  LAC       QB          280.919118   41.820048  43.5
# 12.0         Stefon Diggs  BUF       WR          314.883844  130.920134  11.5
# 2.0   Christian McCaffrey  2TM       RB          357.210003  191.754558   2.0
# 19.0         Tony Pollard  DAL       RB          246.822004   81.366560  19.0
#
#       RankvsADP
# Rank
# 55.0      -50.0
# 50.0      -31.0
# 29.0      -26.0
# 48.0      -16.5
# 43.0       -7.5
# 33.0       -5.0
# 13.0       -4.0
# 15.0       -3.0
# 3.0        -2.0
# 30.0       -2.0
# 14.0       -2.0
# 45.0       -1.5
# 12.0       -0.5
# 2.0         0.0
# 19.0        0.0

# %% [markdown]
# The above shows the top 15 most **over valued** players with VORPS in the 75th percentile calculated using the same method as above. Note that many teams tend to overvalue WR.

# %% [markdown]
# #### Under Valued Players by PPR

# %%
df_results[df_results['PPR_Projected_2023']>=ppr_75th_value].sort_values('RankvsADP', ascending = False).head(n=15)
# Out:
#                  Player Team Position  PPR_Projected_2023       VORP    ADP  \
# Rank
# 27.0  Leonard Fournette  TAM       RB          225.962114  60.506670  164.0
# 24.0         Geno Smith  SEA       QB          305.450818  66.351748  113.0
# 40.0         Jared Goff  DET       QB          283.257415  44.158346  115.0
# 35.0       Kirk Cousins  MIN       QB          292.350294  53.251224  106.0
# 38.0       Daniel Jones  NYG       QB          287.939302  48.840232  108.0
# 28.0    Jamaal Williams  DET       RB          225.652130  60.196686   97.0
# 99.0         Derek Carr  LVR       QB          217.688768 -21.410302  146.5
# 69.0      Aaron Rodgers  GNB       QB          239.099070   0.000000  112.5
# 39.0       Alvin Kamara  NOR       RB          212.411117  46.955673   78.0
# 21.0        Dalvin Cook  MIN       RB          239.356049  73.900605   59.0
# 36.0      Tyler Lockett  SEA       WR          235.036396  51.072686   73.0
# 90.0     Russell Wilson  DEN       QB          225.588961 -13.510109  126.5
# 44.0         Mike Evans  TAM       WR          226.006895  42.043185   78.5
# 34.0     Christian Kirk  JAX       WR          239.007900  55.044190   68.0
# 41.0      Brandon Aiyuk  SFO       WR          227.926204  43.962495   69.0
#
#       RankvsADP
# Rank
# 27.0      137.0
# 24.0       89.0
# 40.0       75.0
# 35.0       71.0
# 38.0       70.0
# 28.0       69.0
# 99.0       47.5
# 69.0       43.5
# 39.0       39.0
# 21.0       38.0
# 36.0       37.0
# 90.0       36.5
# 44.0       34.5
# 34.0       34.0
# 41.0       28.0

# %% [markdown]
# The above shows the top 15 **under valued** players with PPRs in the 75th percentile. Note that there are many quarterbacks included here as despite having some of the highest projected PPRs of all players tend to be drafted later on average.
